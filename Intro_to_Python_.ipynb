# %% [markdown]
# <a href="https://colab.research.google.com/github/FlaviaSilvera/PythonLearning/blob/main/Intro_to_Python_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello python")
# Out:
# hello python

# %%
name="Amit"
age=20
name1="Neeta"
age1=32
print(name)
print(age)
type(name1)
# Out:
# Amit
# 20
# str

# %%
a=5
b=67.4
my_name="Anjali"
_d=True
_a="True"
print(my_name)
print(_d)
print(_a)
# Out:
# Anjali
# True
# True

# %%
name=input("Enter your name:: ")
print("My name is :", name)

age=int(input("Enter your age:: "))
print("You are ", age, "years old")
# Out:
# Enter your name:: Setta
# My name is : Setta
# Enter your age:: 41
# You are  41 years old

# %%
name=input("Enter your name:: ")
age=int(input("Enter your age:: "))
subject=input("Enter your favorite subject:: ")
print("Glad to know :", name, "you are ", age,"years old and your favorote sujbect is :",subject)
# Out:
# Enter your name:: Meena
# Enter your age:: 32
# Enter your favorite subject:: Maths
# Glad to know : Meena you are  32 years old and your favorote sujbect is : Maths
